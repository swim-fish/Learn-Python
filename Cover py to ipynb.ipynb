# %% [markdown]
# Create a notebook containing code from a script.
# Run as:  python make_nb.py my_script.py
#
# ```
# import sys
#
# import nbformat
# from nbformat.v4 import new_notebook, new_code_cell
#
# nb = new_notebook()
# with open(sys.argv[1]) as f:
#     code = f.read()
#
# nb.cells.append(new_code_cell(code))
# nbformat.write(nb, sys.argv[1]+'.ipynb')```

# %% [markdown]
# In notebook use:
# ```%load filename.py```

# %%
import os
import sys

# %%
import nbformat
from nbformat.v4 import new_notebook, new_code_cell
from nbformat import current as nbf
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nbformat/current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %%
# traverse root directory, and list directories as dirs and files as files
for root, dirs, files in os.walk("."):
    path = root.split(os.sep)
    print((len(path) - 1) * '---', os.path.basename(root))
    for file in files:
        print(len(path) * '---', file)
# Out:
#  .
# --- .DS_Store
# --- README.md
# --- Cover py to ipynb.ipynb
# --- matplot
# ------ plot.py
# ------ subplot.py
# ------ legend.py
# ------ figure.py
# ------ barchart.py
# ------ scatter.py
# ------ label.py
# ------ images
# --------- 05_scatter.png
# --------- legend.png
# --------- subplot.png
# --------- label.png
# --------- ticks.png
# --------- 06_subplot.png
# --------- plot.png
# --------- scatter.png
# --------- figure2.png
# --------- figure1.png
# --------- bar.png
# --------- figure1a.png
# --- ipynb
# --- basic
# ------ try.py
# ------ import.py
# ------ comment.py
# ------ test-new.csv
# ------ classLocation.py
# ------ io2.py
# ------ control.py
# ------ io.py
# ------ readCSV.py
# ------ classPeople.py
# ------ logic.py
# ------ var.py
# ------ testc.csv
# ------ grade.csv
# ------ identity_op.py
# ------ testx.xlsx
# ------ age.txt
# ------ assignment.py
# ------ math.py
# ------ string.py
# ------ grade.xlsx
# ------ grade2.csv
# ------ gradebook.py
# ------ collection
# --------- listFunc.py
# --------- listMethod.py
# --------- tuple01.py
# --------- list01.py
# --------- list04.py
# --------- 03_tuple.py
# --------- 04_dic.py
# --------- list03.py
# --------- listGradebook.py
# --------- list02.py
# --------- 04_set.py
# --------- set01.py
# --------- dict01.py
# ------ app
# --------- file.py
# --------- date.py
# --------- .ipynb_checkpoints
# ------ images
# --------- iris.jpg
# --------- ml_map.png
# ------ output
# --------- 02_file.txt
# --------- io2.txt
# ------ class
# --------- abc01.py
# --------- classAttr.py
# --------- getAttr.py
# --------- dataHiding.py
# --------- inheritance02.py
# --------- iterator.py
# --------- class03.py
# --------- staticMethod.py
# --------- classLikeFunction.py
# --------- classProperty.py
# --------- inheritance.py
# ------ .ipynb_checkpoints
# ------ modules
# --------- 10_function.py
# --------- 11_class.py
# --------- 11_class2.py
# --- numpy
# ------ npBroadcasting.py
# ------ npOperation.py
# ------ npDot.py
# ------ npBasic.py
# --- ml
# ------ multiRegression.py
# ------ Salary_Data.csv
# ------ confusionMatrix.py
# ------ labelEncoder.py
# ------ linearRegression.py
# ------ knn_.py
# ------ precisionRecall.py
# ------ 50_Startups.csv
# ------ svm.py
# ------ ads.csv
# ------ normalization.py
# ------ knn_iris_.py
# ------ r2.py
# ------ knn_iris.py
# ------ knn.py
# ------ images
# --------- scale.png
# --------- regressionSalary.png
# --- .ipynb_checkpoints
# ------ Cover py to ipynb-checkpoint.ipynb
# --- .git
# ------ config
# ------ HEAD
# ------ description
# ------ index
# ------ packed-refs
# ------ FETCH_HEAD
# ------ objects
# --------- pack
# ------------ pack-8d84cd78973eebf852221b60bafa0aff728c6a28.pack
# ------------ pack-8d84cd78973eebf852221b60bafa0aff728c6a28.idx
# --------- info
# ------ info
# --------- exclude
# ------ logs
# --------- HEAD
# --------- refs
# ------------ heads
# --------------- master
# ------------ remotes
# --------------- origin
# ------------------ HEAD
# --------------- upstream
# ------------------ master
# ------ hooks
# --------- commit-msg.sample
# --------- pre-rebase.sample
# --------- pre-commit.sample
# --------- applypatch-msg.sample
# --------- fsmonitor-watchman.sample
# --------- pre-receive.sample
# --------- prepare-commit-msg.sample
# --------- post-update.sample
# --------- pre-applypatch.sample
# --------- pre-push.sample
# --------- update.sample
# ------ refs
# --------- heads
# ------------ master
# --------- tags
# --------- remotes
# ------------ origin
# --------------- HEAD
# ------------ upstream
# --------------- master
# ------ lfs
# --------- objects
# ------------ logs
# --------- tmp
# ------------ objects
# ------ branches
# --- pandas
# ------ fruit.csv
# ------ pdCSV.py
# ------ pdMissingData.py
# ------ pdJoin.py
# ------ pdVis.py
# ------ pdFrame.py
# ------ fruitTitle.csv
# ------ pdBasic.py
# ------ images
# --------- twin.png
# --------- seriesPlot.png
# --------- plot.png
# --------- d.png
# --------- dfPlot.png
# ------ .ipynb_checkpoints
# --------- 01panda-checkpoint.ipynb

# %%
for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith('.py'):
            print(os.path.join(root, file))
# Out:
# ./matplot/plot.py
# ./matplot/subplot.py
# ./matplot/legend.py
# ./matplot/figure.py
# ./matplot/barchart.py
# ./matplot/scatter.py
# ./matplot/label.py
# ./basic/try.py
# ./basic/import.py
# ./basic/comment.py
# ./basic/classLocation.py
# ./basic/io2.py
# ./basic/control.py
# ./basic/io.py
# ./basic/readCSV.py
# ./basic/classPeople.py
# ./basic/logic.py
# ./basic/var.py
# ./basic/identity_op.py
# ./basic/assignment.py
# ./basic/math.py
# ./basic/string.py
# ./basic/gradebook.py
# ./basic/collection/listFunc.py
# ./basic/collection/listMethod.py
# ./basic/collection/tuple01.py
# ./basic/collection/list01.py
# ./basic/collection/list04.py
# ./basic/collection/03_tuple.py
# ./basic/collection/04_dic.py
# ./basic/collection/list03.py
# ./basic/collection/listGradebook.py
# ./basic/collection/list02.py
# ./basic/collection/04_set.py
# ./basic/collection/set01.py
# ./basic/collection/dict01.py
# ./basic/app/file.py
# ./basic/app/date.py
# ./basic/class/abc01.py
# ./basic/class/classAttr.py
# ./basic/class/getAttr.py
# ./basic/class/dataHiding.py
# ./basic/class/inheritance02.py
# ./basic/class/iterator.py
# ./basic/class/class03.py
# ./basic/class/staticMethod.py
# ./basic/class/classLikeFunction.py
# ./basic/class/classProperty.py
# ./basic/class/inheritance.py
# ./basic/modules/10_function.py
# ./basic/modules/11_class.py
# ./basic/modules/11_class2.py
# ./numpy/npBroadcasting.py
# ./numpy/npOperation.py
# ./numpy/npDot.py
# ./numpy/npBasic.py
# ./ml/multiRegression.py
# ./ml/confusionMatrix.py
# ./ml/labelEncoder.py
# ./ml/linearRegression.py
# ./ml/knn_.py
# ./ml/precisionRecall.py
# ./ml/svm.py
# ./ml/normalization.py
# ./ml/knn_iris_.py
# ./ml/r2.py
# ./ml/knn_iris.py
# ./ml/knn.py
# ./pandas/pdCSV.py
# ./pandas/pdMissingData.py
# ./pandas/pdJoin.py
# ./pandas/pdVis.py
# ./pandas/pdFrame.py
# ./pandas/pdBasic.py

# %%
for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith('.py'):
            input_file = os.path.join(root, file)
            output_file = input_file[:-2] + "ipynb"
            
            with open(input_file) as f:
                code = f.read()
            
            nb = new_notebook()
            nb.cells.append(new_code_cell(code))
            nbformat.write(nb, output_file)
